# %% [markdown]
# # Sepedi Piper TTS Training Notebook\n\nThis notebook launches the maintained training pipeline from the GitHub repo.\n\n## Before running\n\nSet Colab runtime to:\n\n```text\nRuntime → Change runtime type → T4 GPU\n```\n\nExpected dataset:\n\n```text\n/content/drive/MyDrive/sepedi_tts_dataset.zip\n```\n\nThe pipeline will stop if CUDA is not visible to Python 3.10.

# %%
# Clone latest pipeline and run it\n!rm -rf /content/Colab_Sepedi_TTS\n!git clone https://github.com/JB3Ai/Colab_Sepedi_TTS.git /content/Colab_Sepedi_TTS\n%run /content/Colab_Sepedi_TTS/colab/Sepedi_Piper_TTS_Training.py
